# %% [markdown]
# #ASSIGNMENT
#
# 1. What is the purpose of a PivotTable in Excel?
#     - It is used to summarize , analyze , and organize large amount of data-sets also used to present data to view through different perspective .
#
# 2. Create a PivotTable to show Total Sales by Region.
#     - By using Regions in ROWS , and Product In COLUMNS and Sum of Sales in Values Region . As mentioned in Excel-Worksheet.
#
# 3. Apply Conditional Formatting to highlight sales greater than 400.
#    - Fist to be applied , select the table that you're working on.
#    - Go to Home Page , "Conditional Formatting", then use " Highlight cells rule".
#    - Go to "Greater than" Put [ 400 ] in the box.
#    - Choose "Particular colour" and enter .
#
# 4. Explain the difference between Sorting and Filtering with an example from this dataset.
#    - Sorting - It means sorting data in a specific order. It organizes data in Highest to lowest or lowest to highest.
#    - Filtering - It shows only selected data from that dataset, and hides unwanted data temporarily .
# - Let us try to understand this with an example from our dataset ,
#     -  If we apply sorting on sales column, from largest to smallest. so what happens is rows with highest value appear at the top.
#     - If we apply Filtering , only the data matches certain conditions , Let's say we apply filter on Region column and select North , only those rows where region = North are visible , Other rows will be hidden temporarily .
#
# 5. Create a PivotChart showing Monthly Sales Trend.
#    - Select the dataset and Go to Insert Tab and create Pivot Table on Existing Worksheet, By putting " Product " in columns , and Months( date ) in Rows , and lastly Putting " Sum of sales " in Values .
#
# 6. Use a Slicer to filter data by Product and observe changes in sales.
#     - Fistly Select the DATASET , then create a chart and click on slicer to take slicer by choosing Product and then  by clicking any single product the data of that particular product will be visible on sheet.
#
# 7. Why are Dashboards important for decision-making in business analysis?
#     - Dashboard is a visual tool that display important dataset by uisng multiple tools like : Charts , Tables , KPIs, Graphs and also it helps analysts understand performance quickly and make better decisions .
# - A sales Dashboard may show , Total revenue , Top- selling Product , Region wise sales , Montly sales . It can help management decide which product need promotion , which region needs improvement , future sales strategies .
#
# 8. Why are Dashboards important for decision-making in business analysis?
# Create a Dashboard that includes:
# Sales by Region (PivotTable + Chart)
# Product Filter (Slicer)
# Monthly Trend (Line Chart).
#     - Dashboards are Important for Decisions Making in Business analysis due to following reasons ,
# - Quick Decision Making
# - Better Data Visualization
# - Identifies Trends and Patterns
# - Improves Business Performance
# - Supports Data-Driven Decisions
# - Real-Time Monitoring
#
# 9. Group dates in the PivotTable into Months and calculate the average sales per month.
#    - mentioned in Excel sheet .
#
# 10. Combine Apples and Oranges into one group called Fruits and compare its sales with other products
#     - We have to combine ( Apples and Oranges) into One group by adding a newcolumn into DATASET named "Group" in excel we will use the formula that is mentioned in the Excel sheet, and then we will create a pivot table in which we will compare fruits with other product mango sales .
